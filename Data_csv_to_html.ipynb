# %%
import pandas as pd

# %%
file_one = "Resources/cities_HW.csv"

# %%
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
file_one_df.head()
# Out:
#          City    Lat     Lng Country  Temperature_max(F)  Humidity(%)  \
# 0     ushuaia -54.80  -68.30      AR               48.20         87.0
# 1   pemberton  50.32 -122.80      CA               46.40         93.0
# 2  bredasdorp -34.53   20.04      ZA               64.40         88.0
# 3   berezovyy  51.67  135.70      RU               31.89         91.0
# 4      hobart -42.88  147.33      AU               82.99         36.0
#
#    Cloudness(%)  Wind speed(m/h)                 Date
# 0           0.0             9.17  2020-11-03 02:07:16
# 1          29.0             4.90  2020-11-03 02:07:33
# 2          98.0            11.41  2020-11-03 02:07:33
# 3         100.0             2.35  2020-11-03 02:07:34
# 4           0.0            10.29  2020-11-03 02:05:52

# %%
html_table = file_one_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Country</th>\n      <th>Temperature_max(F)</th>\n      <th>Humidity(%)</th>\n      <th>Cloudness(%)</th>\n      <th>Wind speed(m/h)</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>ushuaia</td>\n      <td>-54.80</td>\n      <td>-68.30</td>\n      <td>AR</td>\n      <td>48.20</td>\n      <td>87.0</td>\n      <td>0.0</td>\n      <td>9.17</td>\n      <td>2020-11-03 02:07:16</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>pemberton</td>\n      <td>50.32</td>\n      <td>-122.80</td>\n      <td>CA</td>\n      <td>46.40</td>\n      <td>93.0</td>\n      <td>29.0</td>\n      <td>4.90</td>\n      <td>2020-11-03 02:07:33</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>bredasdorp</td>\n      <td>-34.53</td>\n      <td>20.04</td>\n      <td>ZA</td>\n      <td>64
# ...

# %%
file_one_df.to_html('data.html')
